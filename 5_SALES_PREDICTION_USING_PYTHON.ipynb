# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('Advertising.csv',index_col = 0)
data
# Out:
#         TV  Radio  Newspaper  Sales
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
data.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4

# %%
data.shape
# Out:
# (200, 4)

# %%
data.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 7.8 KB

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=data,x='TV',y='Sales')
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=data,x='Radio',y='Sales')
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=data,x='Newspaper',y='Sales')
plt.show()

# %%
plt.figure(figsize = (15,8))
for i,z in enumerate(['TV', 'Radio', 'Newspaper']):
    plt.subplot(2,2,i+1)
    sns.histplot(data = data, x = z,kde = True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=data[['TV', 'Radio', 'Newspaper']])
plt.title('Advertising Costs')
# Out:
# Text(0.5, 1.0, 'Advertising Costs')

# %%
sns.pairplot(data)

# %%
sns.pairplot(data = data , hue = 'TV')

# %%
sns.pairplot(data = data , hue = 'Radio')

# %%
sns.pairplot(data = data , hue = 'Newspaper')

# %%
plt.figure(figsize=(6,4))
sns.heatmap(data.corr(),annot=True)
plt.show()
