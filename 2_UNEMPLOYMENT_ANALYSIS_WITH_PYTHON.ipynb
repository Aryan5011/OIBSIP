# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('Unemployment in India.csv')
data2 = pd.read_csv('Unemployment_Rate_upto_11_2020.csv')
data
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
data.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
data.tail()
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 763    NaN   NaN        NaN                               NaN
# 764    NaN   NaN        NaN                               NaN
# 765    NaN   NaN        NaN                               NaN
# 766    NaN   NaN        NaN                               NaN
# 767    NaN   NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Area
# 763                  NaN                                       NaN  NaN
# 764                  NaN                                       NaN  NaN
# 765                  NaN                                       NaN  NaN
# 766                  NaN                                       NaN  NaN
# 767                  NaN                                       NaN  NaN

# %%
data.shape
# Out:
# (768, 7)

# %%
data.isnull()
# Out:
#      Region   Date   Frequency   Estimated Unemployment Rate (%)  \
# 0     False  False       False                             False
# 1     False  False       False                             False
# 2     False  False       False                             False
# 3     False  False       False                             False
# 4     False  False       False                             False
# ..      ...    ...         ...                               ...
# 763    True   True        True                              True
# 764    True   True        True                              True
# 765    True   True        True                              True
# 766    True   True        True                              True
# 767    True   True        True                              True
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0                  False                                     False  False
# ...

# %%
data.isnull().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
data.dropna(axis = 0,inplace= True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 740 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 46.2+ KB

# %%
data.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
data.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
data.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Region                                       object
#  Date                                        object
#  Frequency                                   object
#  Estimated Unemployment Rate (%)            float64
#  Estimated Employed                         float64
#  Estimated Labour Participation Rate (%)    float64
# Area                                         object
# dtype: object

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 749    False
# 750    False
# 751    False
# 752    False
# 753    False
# Length: 740, dtype: bool

# %%
data['Region'].value_counts()
# Out:
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: Region, dtype: int64

# %%
data['Area'].value_counts()
# Out:
# Urban    381
# Rural    359
# Name: Area, dtype: int64

# %%
data[' Frequency'].value_counts()
# Out:
# Monthly     381
#  Monthly    359
# Name:  Frequency, dtype: int64

# %%
data[' Date'].value_counts()
# Out:
#  31-10-2019    55
#  30-11-2019    55
#  31-05-2019    54
#  30-06-2019    54
#  31-07-2019    54
#  31-08-2019    53
#  31-12-2019    53
#  31-01-2020    53
#  29-02-2020    53
#  30-09-2019    52
#  31-03-2020    52
#  30-04-2020    51
#  31-05-2020    51
#  30-06-2020    50
# Name:  Date, dtype: int64

# %%
plt.figure(figsize=(10, 10))
sns.histplot(data[' Estimated Unemployment Rate (%)'], kde=True, bins=20, color="skyblue")
plt.title('Distribution of Unemployment Rate(%)')
plt.xlabel('Estinated Unemployment Rate (%)')
plt.ylabel('Frequency')
plt.show()

# %%
unemployment=data.groupby('Region')[' Estimated Unemployment Rate (%)'].mean()
plt.figure(figsize=(10, 8))
unemployment.plot(kind='barh', color='cyan')
plt.title('Average Unemployment Rate')
plt.xlabel('Average Estimated Unemployment Rate (%)')
plt.ylabel('Region')
plt.show()

# %%
data = pd.DataFrame(data)
y=data[' Estimated Employed']
x=data['Region']
pr= plt.figure(figsize=(40, 15))
plt.xlabel("States",fontsize = 40)
plt.ylabel("Estimated employment rate",fontsize = 40)
plt.xticks(fontweight='bold',rotation='vertical',fontsize=20)
plt.bar(x,y, color='g',align='center')
plt.show()

# %%
plt.figure(figsize=(15, 10))
for i,z in enumerate([' Estimated Unemployment Rate (%)',' Estimated Employed', ' Estimated Labour Participation Rate (%)']):
    plt.subplot(2,2,i+1)
    sns.histplot(x=z, hue="Area", data=data, kde=True, palette="hls")
    plt.title("Estimated Employment Rate by Area")
    plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize = (15,6))
sns.boxplot(x='Region', y=' Estimated Unemployment Rate (%)', data=data,)
plt.title('Estimated Unemployment Rate')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize = (15,6))
sns.boxplot(x='Region', y=' Estimated Labour Participation Rate (%)', data=data,)
plt.title('Estimated Labour Participation Rate')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize =(15,8))
data_grouped = data.groupby('Region')[' Estimated Unemployment Rate (%)'].sum()
data_grouped.plot(kind='pie', autopct='%1.1f%%')
plt.title('Estimated Unemployment Rate')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize =  (15,8))
data_grouped = data.groupby('Region')[' Estimated Labour Participation Rate (%)'].sum()
data_grouped.plot(kind='pie', autopct='%1.1f%%')
plt.title('Estimated Labour Participation Rate')
plt.axis('equal')
plt.show()

# %%
sns.pairplot(data,hue = "Region")

# %%
sns.pairplot(data,hue = "Area",markers="x")

# %%
sns.countplot(x='Area',data=data)
plt.ylabel('Estimated Unemployment Rate (%)')
# Out:
# Text(0, 0.5, 'Estimated Unemployment Rate (%)')

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
data2
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
data2.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
data2.duplicated().sum()
# Out:
# 0

# %%
data2['Region'].value_counts()
# Out:
# Andhra Pradesh      10
# Assam               10
# Uttarakhand         10
# Uttar Pradesh       10
# Tripura             10
# Telangana           10
# Tamil Nadu          10
# Rajasthan           10
# Punjab              10
# Puducherry          10
# Odisha              10
# Meghalaya           10
# Maharashtra         10
# Madhya Pradesh      10
# Kerala              10
# Karnataka           10
# Jharkhand           10
# Himachal Pradesh    10
# Haryana             10
# Gujarat             10
# Goa                 10
# Delhi               10
# Chhattisgarh        10
# Bihar               10
# West Bengal         10
# Jammu & Kashmir      9
# Sikkim               8
# Name: Region, dtype: int64

# %%
data2[' Date'].value_counts()
# Out:
#  31-03-2020    27
#  31-05-2020    27
#  30-06-2020    27
#  31-07-2020    27
#  31-08-2020    27
#  30-09-2020    27
#  31-10-2020    27
#  31-01-2020    26
#  29-02-2020    26
#  30-04-2020    26
# Name:  Date, dtype: int64

# %%
data2['latitude'].value_counts()
# Out:
# 79.0193    20
# 78.6569    20
# 75.7139    20
# 79.7400    10
# 92.9376    10
# 80.9462    10
# 91.9882    10
# 74.2179    10
# 75.3412    10
# 79.8083    10
# 85.0985    10
# 91.3662    10
# 76.2711    10
# 85.2799    10
# 77.1734    10
# 76.0856    10
# 71.1924    10
# 74.1240    10
# 77.1025    10
# 81.8661    10
# 85.3131    10
# 87.8550    10
# 76.5762     9
# 88.5122     8
# Name: latitude, dtype: int64

# %%
data2['longitude'].value_counts()
# Out:
# 15.9129    10
# 26.2006    10
# 30.0668    10
# 26.8467    10
# 23.9408    10
# 18.1124    10
# 11.1271    10
# 27.0238    10
# 31.1471    10
# 11.9416    10
# 20.9517    10
# 25.4670    10
# 19.7515    10
# 22.9734    10
# 10.8505    10
# 15.3173    10
# 23.6102    10
# 31.1048    10
# 29.0588    10
# 22.2587    10
# 15.2993    10
# 28.7041    10
# 21.2787    10
# 25.0961    10
# 22.9868    10
# 33.7782     9
# 27.5330     8
# Name: longitude, dtype: int64

# %%
data2.columns = ["States","Date","Frequency","Estimated Unemployment Rate",
                "Estimated Employed","Estimated Labour Participation Rate",
                "Region","longitude","latitude"]

plt.title("Indian Employment")
sns.histplot(x="Estimated Employed",hue="Region",data=data2)
# Out:
# <Axes: title={'center': 'Indian Employment'}, xlabel='Estimated Employed', ylabel='Count'>

# %%
plt.figure(figsize=(6,4))
plt.title("Indian Unemployment")
sns.histplot(x="Estimated Unemployment Rate",hue="Region",data=data2)
# Out:
# <Axes: title={'center': 'Indian Unemployment'}, xlabel='Estimated Unemployment Rate', ylabel='Count'>

# %%
sns.countplot(x='Region',data=data2)
plt.ylabel('Estimated Unemployment Rate (%)')
# Out:
# Text(0, 0.5, 'Estimated Unemployment Rate (%)')

# %%
freq = data2['Region'].value_counts()
freq.plot(kind='pie',startangle = 140)
print(freq)
plt.legend()
plt.show()
# Out:
# North        79
# South        60
# West         50
# East         40
# Northeast    38
# Name: Region, dtype: int64

# %%
sns.pairplot(data2, hue='longitude')

# %%
sns.pairplot(data2, hue='Region')

# %%
plt.figure(figsize=(6,4))
sns.heatmap(data2.corr(),annot=True)
plt.show()
